# %%
#Import Library
import os
import shutil
import glob
import cv2
import numpy as np
import zipfile

# %%
#Drive Moun
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#GPU 
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
local_zip = '/content/drive/MyDrive/딥러닝 오소리 /Data Set/archive.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
os.makedirs('/tmp/train')
zip_ref.extractall('/tmp/train')
zip_ref.close()

# %%
#데이터를 배열로 초기화
data = {}
data['crack'] = []
data['uncrack'] = []

# %%
#Crack Data
src = '/tmp/train/Positive'
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['crack'].append(jpgImage)
print(len(data['crack']))
# Out:
# 20000

# %%
#Uncrack Data
src = '/tmp/train/Negative'
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['uncrack'].append(jpgImage)
print(len(data['uncrack']))
# Out:
# 20000

# %%
#Create File
os.mkdir('master_data_concrete')
os.mkdir('master_data_concrete/training')
os.mkdir('master_data_concrete/validation')
os.mkdir('master_data_concrete/test')

os.mkdir('master_data_concrete/training/crack')
os.mkdir('master_data_concrete/training/uncrack')
os.mkdir('master_data_concrete/validation/crack')
os.mkdir('master_data_concrete/validation/uncrack')
os.mkdir('master_data_concrete/test/crack')
os.mkdir('master_data_concrete/test/uncrack')

# %%
#Data shuffle
from sklearn.model_selection import train_test_split
import sys

X = data['crack'] #Data
Y = np.zeros((len(data['crack']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.3)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))
# Out:
# X_train Data list = 11200    Y_train Label list = 11200
# X_valid Data list = 4800    Y_valid Label list = 4800
# X_test Data list = 4000    Y_test Label list = 4000

# %%
#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'crack')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'crack')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'crack')
        shutil.copy(image, dest)
# Out:
#   0%|          | 0/11200 [00:00<?, ?it/s]
#   0%|          | 0/4800 [00:00<?, ?it/s]
#   0%|          | 0/4000 [00:00<?, ?it/s]

# %%
base_dest = 'master_data_concrete'
dest = os.path.join(base_dest, 'training','crack')
dest
# Out:
# 'master_data_concrete/training/crack'

# %%
#Data shuffle
X = data['uncrack'] #Data
Y = np.zeros((len(data['uncrack']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.3)
#assert len(X_train) == len(data['crack'])/10*4 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))
# Out:
# X_train Data list = 11200    Y_train Label list = 11200
# X_valid Data list = 4800    Y_valid Label list = 4800
# X_test Data list = 4000    Y_test Label list = 4000

# %%
#image copy
base_dest = 'master_data_concrete'

#copy training  images of uncrack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'uncrack')
        shutil.copy(image, dest)

#copy testing images of uncrack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'uncrack')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'uncrack')
        shutil.copy(image, dest)
# Out:
#   0%|          | 0/11200 [00:00<?, ?it/s]
#   0%|          | 0/4800 [00:00<?, ?it/s]
#   0%|          | 0/4000 [00:00<?, ?it/s]

# %%
#Model Library
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,BatchNormalization
from keras.callbacks  import EarlyStopping, LambdaCallback
from keras.layers import Activation, Dropout,Input, Flatten, Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator

# %%
#Convolutional Layer
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 1)))  #size 227 -> 150
model.add(BatchNormalization(axis=-1)) #Normalize Batch
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))






#Output Layer
model.add(Flatten())  #3D를 1D로 벡터 변환
model.add(Dense(128))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.4))

model.add(Dense(64))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(1)) 
model.add(BatchNormalization(axis=-1))
model.add(Activation('sigmoid'))  #or model.add(Activation('softmax')) // two output softmax == one output sigmoid

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_59 (Conv2D)           (None, 148, 148, 32)      320
# _________________________________________________________________
# batch_normalization_85 (Batc (None, 148, 148, 32)      128
# _________________________________________________________________
# activation_85 (Activation)   (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 72, 72, 64)        18496
# _________________________________________________________________
# batch_normalization_86 (Batc (None, 72, 72, 64)        256
# _________________________________________________________________
# activation_86 (Activation)   (None, 72, 72, 64)        0
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 34, 34, 128)       73856
# _________________________________________________________________
# batch_normalization_87 (Batc (None, 34, 34, 128)       512
# _________________________________________________________________
# activation_87 (Activation)   (None, 34, 34, 128)       0
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 36992)             0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               4735104
# _________________________________________________________________
# batch_normalization_88 (Batc (None, 128)               512
# _________________________________________________________________
# activation_88 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_89 (Batc (None, 64)                256
# _________________________________________________________________
# activation_89 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 65
# _________________________________________________________________
# batch_normalization_90 (Batc (None, 1)                 4
# _________________________________________________________________
# activation_90 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 4,837,765
# Trainable params: 4,836,931
# Non-trainable params: 834
# _________________________________________________________________

# %%
#tf.keras.preprocessing.image_dataset_from_directory(
#    directory, labels='inferred', label_mode='int',
 #   class_names=None, color_mode='rgb', batch_size=32, image_size=(256,
 #   256), shuffle=True, seed=None, validation_split=None, subset=None,
 #   interpolation='bilinear', follow_links=False, smart_resize=False
#)

# %%
from keras.preprocessing.image import ImageDataGenerator

batch_size = 64
epochs = 20

#스케일 조정 및 과적합 방지
train_datagen = ImageDataGenerator (
        rescale=1./255, 
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

#validation,test에 사용할 확장구성
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

#train, validation, test 모든 이미지 크기 = 150*150
train_generator = train_datagen.flow_from_directory(
        '/content/master_data_concrete/training',  
        target_size=(150, 150), 
        batch_size=batch_size,
        shuffle=True,
        color_mode='grayscale',
        class_mode='binary')   #binary_crossentropy loss를 사용하기 위한 binary label

#검증 데이터
validation_generator = validation_datagen.flow_from_directory(
        '/content/master_data_concrete/validation',
        target_size=(150, 150),
        batch_size=batch_size,
        shuffle=True,
        color_mode='grayscale',
        class_mode='binary')

#테스트 데이터
test_generator = test_datagen.flow_from_directory(
       '/content/master_data_concrete/test',
       target_size=(150, 150),
       batch_size=batch_size,
       color_mode='grayscale',
        class_mode='binary')
# Out:
# Found 22400 images belonging to 2 classes.
# Found 9600 images belonging to 2 classes.
# Found 8000 images belonging to 2 classes.

# %%
#Generator Data Verification
#train_ver = next(iter(train_generator))
#print('train_generator: ', train_ver)

#validation_ver = next(iter(validation_generator))
#print('validation_generator: ', validation_ver)

#test_ver = next(iter(test_generator))
#print('test_generator: ', test_ver)

# %%
#만약 overfitting, underfitting 을 일으키면 EarlyStopping을 쓰기 위한 코드  or callback 함수 적용
#patience가 5면 validation score가 5회 이상 개선이 없을때 훈련을 멈춘다

from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.005)

# %%
#Model Learning
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) #rmsprop or adam or sgd , accuracy or f1-score  (positive와 negative의 데이터 값 차이가 높을 경우)
history = model.fit_generator(
        train_generator,
        epochs=epochs,
        validation_data=validation_generator
        ,callbacks=[es])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 350/350 [==============================] - 101s 283ms/step - loss: 0.3066 - accuracy: 0.9773 - val_loss: 0.8121 - val_accuracy: 0.5000
# Epoch 2/20
# 350/350 [==============================] - 99s 283ms/step - loss: 0.2255 - accuracy: 0.9897 - val_loss: 0.1941 - val_accuracy: 0.9882
# Epoch 3/20
# 350/350 [==============================] - 99s 284ms/step - loss: 0.1778 - accuracy: 0.9920 - val_loss: 0.1663 - val_accuracy: 0.9812
# Epoch 4/20
# 350/350 [==============================] - 99s 283ms/step - loss: 0.1446 - accuracy: 0.9925 - val_loss: 0.1521 - val_accuracy: 0.9757
# Epoch 5/20
# 350/350 [==============================] - 99s 283ms/step - loss: 0.1178 - accuracy: 0.9943 - val_loss: 0.1007 - val_accuracy: 0.9944
# Epoch 6/20
# 350/350 [==============================] - 99s 282ms/step - loss: 0.0979 - accuracy: 0.9947 - val_loss: 0.1250 - val_accuracy: 0.9674
# Epoch 7/20
# 350/350 [==============================] - 99s 282ms/step - loss: 0.0828 - accuracy: 0.9950 - val_loss: 0.0717 - val_accuracy: 0.9948
# Epoch 8/20
# 350/350 [==============================] - 99s 281ms/step - loss: 0.0694 - accuracy: 0.9963 - val_loss: 0.0616 - val_accuracy: 0.9968
# Epoch 9/20
# 350/350 [==============================] - 99s 282ms/step - loss: 0.0596 - accuracy: 0.9963 - val_loss: 0.2029 - val_accuracy: 0.9226
# Epoch 10/20
# 350/350 [==============================] - 99s 282ms/step - loss: 0.0519 - accuracy: 0.9968 - val_loss: 0.0510 - val_accuracy: 0.9957

# %%
#훈련 및 검증 정확도 시각화
#학습 정확성 값과 검증 정확성 값
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# 학습 손실 값과 검증 손실 값
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# %%
#model test
loss, accuracy = model.evaluate_generator(test_generator)
print('test loss: ', loss, '\ntest accuracy: ', accuracy)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# test loss:  0.05033305287361145
# test accuracy:  0.9963750243186951

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpc3vfe21q/assets
# INFO:tensorflow:Assets written to: /tmp/tmpc3vfe21q/assets
